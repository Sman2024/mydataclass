# %% [markdown]
# <a href="https://colab.research.google.com/github/Sman2024/mydataclass/blob/main/Mobile_Dataset(2025).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("Mobiles Dataset (2025).csv",encoding="latin1")

# %%
df.head(10)
# Out:
#   Company Name               Model Name Mobile Weight  RAM Front Camera  \
# 0        Apple          iPhone 16 128GB          174g  6GB         12MP
# 1        Apple          iPhone 16 256GB          174g  6GB         12MP
# 2        Apple          iPhone 16 512GB          174g  6GB         12MP
# 3        Apple     iPhone 16 Plus 128GB          203g  6GB         12MP
# 4        Apple     iPhone 16 Plus 256GB          203g  6GB         12MP
# 5        Apple     iPhone 16 Plus 512GB          203g  6GB         12MP
# 6        Apple      iPhone 16 Pro 128GB          206g  6GB    12MP / 4K
# 7        Apple      iPhone 16 Pro 256GB          206g  8GB    12MP / 4K
# 8        Apple      iPhone 16 Pro 512GB          206g  8GB    12MP / 4K
# 9        Apple  iPhone 16 Pro Max 128GB          221g  6GB    12MP / 4K
#
#    Back Camera   Processor Battery Capacity Screen Size  \
# 0         48MP  A17 Bionic         3,600mAh  6.1 inches
# 1         48MP  A17 Bionic         3,600mAh  6.1 inches
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    object
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
#  5   Back Camera                930 non-null    object
#  6   Processor                  930 non-null    object
#  7   Battery Capacity           930 non-null    object
#  8   Screen Size                930 non-null    object
#  9   Launched Price (Pakistan)  930 non-null    object
#  10  Launched Price (India)     930 non-null    object
#  11  Launched Price (China)     930 non-null    object
#  12  Launched Price (USA)       930 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Company Name                 0
# Model Name                   0
# Mobile Weight                0
# RAM                          0
# Front Camera                 0
# Back Camera                  0
# Processor                    0
# Battery Capacity             0
# Screen Size                  0
# Launched Price (Pakistan)    0
# Launched Price (India)       0
# Launched Price (China)       0
# Launched Price (USA)         0
# Launched Price (Dubai)       0
# Launched Year                0
# dtype: int64

# %%
df.describe()
# Out:
#        Launched Year
# count     930.000000
# mean     2022.193548
# std         1.862080
# min      2014.000000
# 25%      2021.000000
# 50%      2023.000000
# 75%      2024.000000
# max      2025.000000

# %% [markdown]
# The above table shows the count, mean, standard deviation, min, 25%, 50%, 75% and max values for each column. When we carefully observe the table we will find that Insulin, Pregnancies, BMI, BloodPressure columns has outliers.

# %% [markdown]
# Let plot number of Models by Company(In Dataset)

# %%
model_count_by_company = df['Company Name'].value_counts()

plt.figure(figsize=(12, 6))
model_count_by_company.plot(kind='bar', color='orange')
plt.title('Number of Models by Company(In Datasets)', fontsize=16)
plt.xlabel('Company', fontsize=14)
plt.ylabel('Number of Models', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Distribution** **of** **Screen** **Size**

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Screen Size'], bins=20, color='purple', edgecolor='black')
plt.title('Distribution of Screen Sizes', fontsize=16)
plt.xlabel('Screen Size (inches)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
numberOfModelLonch=df["Launched Year"].value_counts()

# %%
numberOfModelLonch.plot(kind ="bar", color= "green")
# Out:
# <Axes: xlabel='Launched Year'>

# %%
df["Screen Size"].value_counts()
# Out:
# Screen Size
# 6.7 inches               124
# 6.5 inches                76
# 6.67 inches               69
# 6.6 inches                64
# 6.78 inches               61
#                         ...
# 8.0 inches (unfolded)      1
# 7.8 inches (unfolded)      1
# 5.0 inches                 1
# 7.93 inches                1
# 6.79 inches                1
# Name: count, Length: 97, dtype: int64

# %%
phones_2024 = df[df['Launched Year'] == 2024]

if not phones_2024.empty:
    print("Phones Released in 2024:")
    print(phones_2024[['Company Name', 'Model Name','RAM', 'Battery Capacity', 'Screen Size']])
else:
    print("No phones were released in 2024.")
# Out:
# Phones Released in 2024:
#     Company Name            Model Name   RAM Battery Capacity  Screen Size
# 0          Apple       iPhone 16 128GB   6GB         3,600mAh   6.1 inches
# 1          Apple       iPhone 16 256GB   6GB         3,600mAh   6.1 inches
# 2          Apple       iPhone 16 512GB   6GB         3,600mAh   6.1 inches
# 3          Apple  iPhone 16 Plus 128GB   6GB         4,200mAh   6.7 inches
# 4          Apple  iPhone 16 Plus 256GB   6GB         4,200mAh   6.7 inches
# ..           ...                   ...   ...              ...          ...
# 925         Poco          Pad 5G 128GB   8GB        10,000mAh  12.1 inches
# 926         Poco          Pad 5G 256GB   8GB        10,000mAh  12.1 inches
# 927      Samsung  Galaxy Z Fold6 256GB  12GB          4400mAh   7.6 inches
# 928      Samsung  Galaxy Z Fold6 512GB  12GB          4400mAh   7.6 inches
# 929      Samsung    Galaxy Z Fold6 1TB  12GB          4400mAh   7.6 inches
#
# [292 rows x 5 columns]

# %%
phones_2025 = df[df['Launched Year'] == 2025]

if not phones_2025.empty:
    print("Phones Released in 2025:")
    print(phones_2025[['Company Name', 'Model Name','RAM', 'Battery Capacity', 'Screen Size']])
else:
    print("No phones were released in 2025.")
# Out:
# Phones Released in 2025:
#     Company Name         Model Name   RAM Battery Capacity  Screen Size
# 328         Oppo  Reno13 F 4G 256GB   8GB          5800mAh  6.67 inches
# 329         Oppo     Reno13 F 256GB   8GB          5800mAh  6.67 inches
# 330         Oppo   Reno13 Pro 512GB  12GB          5800mAh  6.83 inches
# 331         Oppo       Reno13 256GB  12GB          5600mAh  6.59 inches
# 460       Realme   14 Pro+ 5G 256GB  12GB         6,000mAh  6.83 inches
# 461       Realme   14 Pro+ 5G 512GB  12GB         6,000mAh  6.83 inches
# 462       Realme    14 Pro 5G 128GB   8GB         5,800mAh   6.7 inches
# 463       Realme    14 Pro 5G 256GB   8GB         5,800mAh   6.7 inches
# 464       Realme       14x 5G 128GB   6GB         5,500mAh   6.6 inches
# 465       Realme       14x 5G 256GB   8GB         5,500mAh   6.6 inches
# 922         POCO           X7 128GB   6GB          5000mAh  6.67 inches
# 923         POCO       X7 Pro 256GB   8GB          6000mAh  6.67 inches

# %%
samsung_phones = df[df['Company Name'].str.lower() == 'samsung']

samsung_2025 = samsung_phones[samsung_phones['Launched Year'] == 2025]

if not samsung_2025.empty:
    print("Samsung Phones Launched in 2025:")
    print(samsung_2025[['Company Name', 'Model Name', 'RAM', 'Battery Capacity', 'Screen Size']])
else:
    print("No Samsung phones were launched in 2025.")
# Out:
# No Samsung phones were launched in 2025.

# %%
samsung_phones = df[df['Company Name'].str.lower() == 'samsung']

samsung_2024 = samsung_phones[samsung_phones['Launched Year'] == 2024]

if not samsung_2024.empty:
    print("Samsung Phones Launched in 2024:")
    print(samsung_2024[['Company Name', 'Model Name', 'RAM', 'Battery Capacity', 'Screen Size']])
else:
    print("No Samsung phones were launched in 2024.")
# Out:
# Samsung Phones Launched in 2024:
#     Company Name                 Model Name   RAM Battery Capacity Screen Size
# 97       Samsung     Galaxy S24 Ultra 128GB  12GB          5000mAh  6.8 inches
# 98       Samsung     Galaxy S24 Ultra 256GB  12GB          5000mAh  6.8 inches
# 99       Samsung          Galaxy S24+ 128GB   8GB          4800mAh  6.6 inches
# 100      Samsung          Galaxy S24+ 256GB   8GB          4800mAh  6.6 inches
# 101      Samsung           Galaxy S24 128GB   8GB          4000mAh  6.1 inches
# 102      Samsung           Galaxy S24 256GB   8GB          4000mAh  6.1 inches
# 177      Samsung  Galaxy Tab Active 5 128GB   6GB          5050mAh    8 inches
# 927      Samsung       Galaxy Z Fold6 256GB  12GB          4400mAh  7.6 inches
# 928      Samsung       Galaxy Z Fold6 512GB  12GB          4400mAh  7.6 inches
# 929      Samsung         Galaxy Z Fold6 1TB  12GB          4400mAh  7.6 inches

# %%
samsung_phones = df.loc[df['Company Name'] == 'Samsung'].copy()
apple_phones = df.loc[df['Company Name'] == 'Apple'].copy()


samsung_phones['Mobile Weight'] = pd.to_numeric(samsung_phones['Mobile Weight'].str.replace('g', '').str.replace(' ', ''), errors='coerce')
apple_phones['Mobile Weight'] = pd.to_numeric(apple_phones['Mobile Weight'].str.replace('g', '').str.replace(' ', ''), errors='coerce')


avg_samsung_weight = samsung_phones['Mobile Weight'].mean()
avg_apple_weight = apple_phones['Mobile Weight'].mean()


print("Samsung average weight: ", avg_samsung_weight, "g")
print("Apple average weight: ", avg_apple_weight, "g")
# Out:
# Samsung average weight:  256.6931818181818 g
# Apple average weight:  258.07216494845363 g

# %%
plt.figure(figsize=(10, 6))
plt.bar(['Samsung', 'Apple'], [avg_samsung_weight, avg_apple_weight])
plt.xlabel('Company Name')
plt.ylabel('Average Weight (g)')
plt.title('Samsung vs Apple: Average Phone Weight')
plt.tight_layout()
plt.show()

# %%
df['Front Camera'] = df['Front Camera'].str.extract('(\d+)', expand=False).astype(float)

top_10_phones = df.nlargest(10, 'Front Camera')

plt.figure(figsize=(10, 6))
plt.bar(top_10_phones['Model Name'], top_10_phones['Front Camera'])
plt.xlabel('Model Name')
plt.ylabel('Front Camera Resolution')
plt.title('Top 10 Phones by Front Camera Resolution')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
df['Battery Capacity'] = df['Battery Capacity'].str.replace('mAh', '').str.replace(',', '').astype(float)

df['RAM'] = df['RAM'].str.replace('GB', '').str.replace('/', '').str.replace(' ', '').astype(float)

df['Launched Price (India)'] = df['Launched Price (India)'].str.replace('INR ', '').str.replace(',', '').astype(float)

le = LabelEncoder()
df['Processor'] = le.fit_transform(df['Processor'])

corr_matrix = df[['Battery Capacity', 'RAM', 'Processor', 'Launched Price (India)']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
vivo_phones = df[df['Company Name'].str.lower() == 'vivo']


processor_counts = vivo_phones['Processor'].value_counts()


plt.figure(figsize=(12, 6))
processor_counts.plot(kind='bar', color='purple')
plt.title('Most Commonly Used Processors in Vivo Phones', fontsize=16)
plt.xlabel('Processor', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(rotation=45)
plt.grid(True)


for i, count in enumerate(processor_counts):
    plt.text(i, count, f'{count}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
tecno_phones = df[df['Company Name'].str.lower() == 'tecno']


processor_counts = tecno_phones['Processor'].value_counts()

plt.figure(figsize=(12, 6))
processor_counts.plot(kind='bar', color='red')
plt.title('Most Commonly Used Processors in tecno Phones', fontsize=16)
plt.xlabel('Processor', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(rotation=45)
plt.grid(True)


for i, count in enumerate(processor_counts):
    plt.text(i, count, f'{count}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
honor_phones = df[df['Company Name'].str.lower() == 'honor']


processor_counts = honor_phones['Processor'].value_counts()

plt.figure(figsize=(12, 6))
processor_counts.plot(kind='bar', color='pink')
plt.title('Most Commonly Used Processors in Honor Phones', fontsize=16)
plt.xlabel('Processor', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(rotation=45)
plt.grid(True)


for i, count in enumerate(processor_counts):
    plt.text(i, count, f'{count}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
def clean_price(price):
    if isinstance(price, str):

        price = price.replace('USD', '').replace(',', '').strip()
        if price.isdigit():
            return int(price)
    return None

    df['Launched Price (USA)'] = df['Launched Price (USA)'].apply(clean_price)
    df = df.dropna(subset=['Launched Price (USA)'])
    df['Launched Price (USA)'] = pd.to_numeric(df['Launched Price (USA)'], errors='coerce')

    vivo_phones = df[df['Company Name'].str.lower() == 'vivo']

    top_10_expensive_vivo_usa = vivo_phones.nlargest(10, 'Launched Price (USA)')


    plt.figure(figsize=(12, 6))
    plt.bar(top_10_expensive_vivo_usa['Model Name'], top_10_expensive_vivo_usa['Launched Price (USA)'], color='red')
    plt.title('Top 10 Most Expensive Vivo Phones in USA', fontsize=16)
    plt.xlabel('Model Name', fontsize=14)
    plt.ylabel('Price (USD)', fontsize=14)
    plt.xticks(rotation=90)
    plt.grid(True)


    for i, price in enumerate(top_10_expensive_vivo_usa['Launched Price (USA)']):
        plt.text(i, price, f'{price:,}', ha='center', va='bottom')

    plt.tight_layout()
    plt.show()

# %%
def clean_price(price):
    if isinstance(price, str):

        price = price.replace('CNY', '').replace(',', '').strip()
        if price.isdigit():
            return int(price)
    return None

df['Launched Price (China)'] = df['Launched Price (China)'].apply(clean_price)
df = df.dropna(subset=['Launched Price (China)'])
df['Launched Price (China)'] = pd.to_numeric(df['Launched Price (China)'], errors='coerce')


samsung_phones = df[df['Company Name'].str.lower() == 'samsung']


top_10_expensive_samsung_china = samsung_phones.nlargest(10, 'Launched Price (China)')


plt.figure(figsize=(12, 6))
plt.bar(top_10_expensive_samsung_china['Model Name'], top_10_expensive_samsung_china['Launched Price (China)'], color='blue')
plt.title('Top 10 Most Expensive Samsung Phones in China', fontsize=16)
plt.xlabel('Model Name', fontsize=14)
plt.ylabel('Price (CNY)', fontsize=14)
plt.xticks(rotation=90)
plt.grid(True)


for i, price in enumerate(top_10_expensive_samsung_china['Launched Price (China)']):
    plt.text(i, price, f'{price:,}', ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-113-149de63f5913>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Launched Price (China)'] = pd.to_numeric(df['Launched Price (China)'], errors='coerce')

# %% [markdown]
# Congratulation
